# %%
import numpy as np
a=np.random.randint(0, 1000, 100)
a[(a%2==0) & (a>a.mean())]
# Out:
# array([584, 902, 724, 624, 678, 578, 932, 962, 828, 726, 834, 818, 902,
#        864, 690, 794, 578, 628, 706, 902, 760, 958, 792, 658, 802, 898,
#        904, 716])
