# %%
aa="""vrrp
  interface smartgroup5.462
    vrrp 2 accept
    vrrp 2 ipv4 10.150.39.131
    vrrp 2 timers advertise 3
  
  interface smartgroup5.464
    vrrp 4 accept
    vrrp 4 ipv4 10.150.39.147
    vrrp 4 timers advertise 4
  
  interface smartgroup5.465
    vrrp 5 accept
    vrrp 5 ipv4 10.150.39.155
    vrrp 5 timers advertise 4
  
            interface smartgroup5.466
    vrrp 6 accept
    vrrp 6 ipv4 10.150.39.163
    vrrp 6 timers advertise 4
  
  interface smartgroup5.467
    vrrp 7 accept
    vrrp 7 ipv4 10.150.35.107
    vrrp 7 timers advertise 4
  
  interface smartgroup5.468
    vrrp 8 accept
    vrrp 8 ipv4 10.150.35.115
    vrrp 8 timers advertise 4
  
  interface smartgroup5.463
    vrrp 3 accept
    vrrp 3 ipv4 10.150.39.139
    vrrp 3 timers advertise 4
  
  interface vlan204
    vrrp 10 accept
    vrrp 10 ipv4 105.234.160.254
    vrrp 10 timers advertise 4
  
  interface smartgroup5.461
    vrrp 1 accept
    vrrp 1 ipv4 10.150.39.123
    vrrp 1 timers advertise 4
  
  interface smartgroup5.469
    vrrp 9 accept
    vrrp 9 ipv4 10.150.35.131
    vrrp 9 timers advertise 4
  
  interface vlan194
    vrrp 11 accept
              vrrp 11 ipv4 105.234.160.238
    vrrp 11 timers advertise 4
  
  interface smartgroup5.470
    vrrp 12 accept
    vrrp 12 ipv4 10.150.35.139
    vrrp 12 timers advertise 4
  
  interface smartgroup5.492
    vrrp 15 accept
    vrrp 15 ipv4 10.150.23.67
    vrrp 15 timers advertise 3
  
  interface smartgroup5.472
    vrrp 14 accept
    vrrp 14 ipv4 10.150.35.187
    vrrp 14 timers advertise 4
  
  interface smartgroup5.495
    vrrp 17 accept
    vrrp 17 ipv4 10.150.23.57
    vrrp 17 timers advertise 3
  
  interface smartgroup5.488
    vrrp 18 accept
    vrrp 18 ipv4 10.150.22.182
    vrrp 18 timers advertise 4
  
  interface vlan700
    vrrp 19 accept
    vrrp 19 ipv4 10.150.149.30
    vrrp 19 timers advertise 4
  
  interface smartgroup11.801
    vrrp 22 accept
    vrrp 22 ipv4 192.168.32.254
    vrrp 22 timers advertise 4
            
  interface smartgroup11.804
    vrrp 23 accept
    vrrp 23 ipv4 10.150.149.46
    vrrp 23 timers advertise 4
  
  interface smartgroup11.805
    vrrp 20 accept
    vrrp 20 ipv4 10.150.149.62
    vrrp 20 timers advertise 4
  
  interface smartgroup11.806
    vrrp 21 accept
    vrrp 21 ipv4 192.168.48.254
    vrrp 21 timers advertise 4
  
  interface smartgroup11.807
    vrrp 22 accept
    vrrp 22 ipv4 192.168.42.254
    vrrp 22 timers advertise 4
  
  interface smartgroup11.808
    vrrp 23 accept
    vrrp 23 ipv4 192.168.3.254
    vrrp 23 timers advertise 4
  
  interface smartgroup11.809
    vrrp 24 accept
    vrrp 24 ipv4 192.168.64.254
    vrrp 24 timers advertise 4
  
  interface smartgroup11.1330
    vrrp 25 accept
    vrrp 25 ipv4 10.150.149.94
    vrrp 25 ipv4 10.150.184.254 secondary
    vrrp 25 timers advertise 4
  
            interface smartgroup11.1331
    vrrp 26 accept
    vrrp 26 ipv4 10.150.149.126
    vrrp 26 timers advertise 4
  
  interface smartgroup11.1334
    vrrp 27 accept
    vrrp 27 ipv4 10.150.149.158
    vrrp 27 timers advertise 4
  
  interface smartgroup11.1335
    vrrp 28 accept
    vrrp 28 ipv4 10.150.149.190
    vrrp 28 timers advertise 4
  
  interface smartgroup11.1336
    vrrp 29 accept
    vrrp 29 ipv4 172.16.20.254
    vrrp 29 timers advertise 4
  
  interface smartgroup11.2030
    vrrp 30 accept
    vrrp 30 ipv4 10.150.168.254
    vrrp 30 timers advertise 4
  
  interface smartgroup11.1301
    vrrp 31 accept
    vrrp 31 ipv4 10.150.168.6
    vrrp 31 timers advertise 4
  
  interface smartgroup11.1302
    vrrp 32 accept
    vrrp 32 ipv4 10.150.168.14
    vrrp 32 timers advertise 4
  
  interface smartgroup11.1303
    vrrp 33 accept
              vrrp 33 ipv4 10.150.168.22
    vrrp 33 timers advertise 4
  
  interface smartgroup11.1304
    vrrp 34 accept
    vrrp 34 ipv4 10.150.168.30
    vrrp 34 timers advertise 4
  
  interface smartgroup11.1305
    vrrp 35 accept
    vrrp 35 ipv4 10.150.168.38
    vrrp 35 timers advertise 4
  
  interface smartgroup11.1307
    vrrp 37 accept
    vrrp 37 ipv4 10.150.168.54
    vrrp 37 timers advertise 4
  
  interface smartgroup11.1306
    vrrp 36 accept
    vrrp 36 ipv4 10.150.168.46
    vrrp 36 timers advertise 
"""
b=[]
rr=[]
for a in aa.split('\n'):
    if 'inter' in a:
        b.clear()
        b.append(a)
    if 'inter' not in a:
        b.append(a)
        #print(b)
    if 'advertise 4' in a:        
        print('\t'.join([b[0].strip("interface "),b[2].split(' ')[-1]]))
# Out:
# martgroup5.463	10.150.39.139
# martgroup5.464	10.150.39.147
# martgroup5.465	10.150.39.155
# martgroup5.466	10.150.39.163
# martgroup5.467	10.150.35.107
# martgroup5.468	10.150.35.115
# vlan204	105.234.160.254
# martgroup5.461	10.150.39.123
# martgroup5.469	10.150.35.131
# vlan194	105.234.160.238
# martgroup5.470	10.150.35.139
# martgroup5.472	10.150.35.187
# martgroup5.488	10.150.22.182
# vlan700	10.150.149.30
# martgroup11.801	192.168.32.254
# martgroup11.804	10.150.149.46
# martgroup11.805	10.150.149.62
# martgroup11.806	192.168.48.254
# martgroup11.807	192.168.42.254
# martgroup11.808	192.168.3.254
# martgroup11.809	192.168.64.254
# martgroup11.1330	10.150.149.94
# martgroup11.1331	10.150.149.126
# martgroup11.1334	10.150.149.158
# martgroup11.1335	10.150.149.190
# martgroup11.1336	172.16.20.254
# martgroup11.2030	10.150.168.254
# martgroup11.1301	10.150.168.6
# martgroup11.1302	10.150.168.14
# martgroup11.1303	10.150.168.22
# martgroup11.1304	10.150.168.30
# martgroup11.1305	10.150.168.38
# martgroup11.1307	10.150.168.54
# martgroup11.1306	10.150.168.46

# %%
def indexconvert():
    ss='\n'+ open('myfiles/srte').read()
    ss = ss.replace('label 160', 'adjacency 10.88.38.').replace('01', '1').replace('02', '2').replace('03', '3').replace(
            '04', '4').replace('05', '5').replace('06', '6').replace('07', '7').replace('08', '8').replace('09', '9')
    #print(ss)

    pp=[]
    pp2=[]
    ip = {}
    for a in ss.split('\n'):
        if a=='': continue
        aa=a.split(' ')
        xx=aa[3].split('_SID')[0]
        ip.update({xx:aa[-1].split('.')[-1]})
        #print(ip.get(xx))
        pp.append(aa[3])
        pp2.append(aa[3].split('_SID')[0])

    gp =sorted(set(pp))
    gp2=sorted(set(pp2))
    out='\n\n'
    out4 = '\ncommit\n'
    out2='\n'
    out3= '\n'.join([f'no segment-routing traffic-eng segment-list {a}' for a in gp ])
    #print('\n'.join(gp2))
    for g2 in gp2:
        out+=f"""segment-routing traffic-eng segment-list {g2}_IGP
segment-routing traffic-eng segment-list {g2}_IGP index 10 mpls adjacency 10.88.38.{ip.get(g2)}\n"""
        out2+= f"""segment-routing traffic-eng policy {g2} 
segment-routing traffic-eng policy {g2} color {ip.get(g2)} end-point ipv4 10.88.38.{ip.get(g2)}
segment-routing traffic-eng policy {g2} autoroute 
segment-routing traffic-eng policy {g2} autoroute force-sr-include
segment-routing traffic-eng policy {g2} autoroute include ipv4 10.88.38.{ip.get(g2)}/32
segment-routing traffic-eng policy {g2} candidate-paths 
segment-routing traffic-eng policy {g2} candidate-paths preference 1 
segment-routing traffic-eng policy {g2} candidate-paths preference 1 explicit segment-list {g2}_IGP 
segment-routing traffic-eng policy {g2} candidate-paths preference 200\n"""
    
        for g in gp:
            if g2 in g:
                out2+=f'segment-routing traffic-eng policy {g2} candidate-paths preference 200 explicit segment-list {g}\n'
    print(out3,out4,out,ss,out2)    

indexconvert()
# Out:
# no segment-routing traffic-eng segment-list MR3_AR1_SID1
# no segment-routing traffic-eng segment-list MR3_AR1_SID2
# no segment-routing traffic-eng segment-list MR3_AR2_SID1
# no segment-routing traffic-eng segment-list MR3_AR2_SID2
# no segment-routing traffic-eng segment-list MR3_DO1_SID1
# no segment-routing traffic-eng segment-list MR3_DO1_SID2
# no segment-routing traffic-eng segment-list MR3_DO2_SID1
# no segment-routing traffic-eng segment-list MR3_DO2_SID2
# no segment-routing traffic-eng segment-list MR3_KJ3_SID1
# no segment-routing traffic-eng segment-list MR3_KJ3_SID2
# no segment-routing traffic-eng segment-list MR3_KJ4_SID1
# no segment-routing traffic-eng segment-list MR3_KJ4_SID2
# no segment-routing traffic-eng segment-list MR3_LU1_SID1
# no segment-routing traffic-eng segment-list MR3_LU1_SID2
# no segment-routing traffic-eng segment-list MR3_LU2_SID1
# no segment-routing traffic-eng segment-list MR3_LU2_SID2
# no segment-routing traffic-eng segment-list MR3_MG1_SID1
# no segment-routing traffic-eng segment-list MR3_MG1_SID2
# no segment-routing traffic-eng segment-list MR3_MG2_SID1
# no segment-routing traffic-eng segment-list MR3_MG2_SID2
# no segment-routing traffic-eng segment-list MR3_MW1_SID1
# no segment-routing traffic-eng segment-list MR3_MW1_SID2
# no segment-routing traffic-eng segment-list MR3_MW1_SID3
# no segment-routing traffic-eng segment-list MR3_MW1_SID4
# no segment-routing traffic-eng segment-list MR3_MW2_SID1
# no segment-routing traffic-eng segment-list MR3_MW2_SID2
# no segment-routing traffic-eng segment-list MR3_MW2_SID3
# no segment-routing traffic-eng segment-list MR3_MW2_SID4
# commit
#
#
# segment-routing traffic-eng segment-list MR3_AR1_IGP
# segment-routing traffic-eng segment-list MR3_AR1_IGP index 10 mpls adjacency 10.88.38.11
# segment-routing traffic-eng segment-list MR3_AR2_IGP
# segment-routing traffic-eng segment-list MR3_AR2_IGP index 10 mpls adjacency 10.88.38.12
# segment-routing traffic-eng segment-list MR3_DO1_IGP
# segment-routing traffic-eng segment-list MR3_DO1_IGP index 10 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MR3_DO2_IGP
# segment-routing traffic-eng segment-list MR3_DO2_IGP index 10 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MR3_KJ3_IGP
# segment-routing traffic-eng segment-list MR3_KJ3_IGP index 10 mpls adjacency 10.88.38.8
# segment-routing traffic-eng segment-list MR3_KJ4_IGP
# segment-routing traffic-eng segment-list MR3_KJ4_IGP index 10 mpls adjacency 10.88.38.9
# segment-routing traffic-eng segment-list MR3_LU1_IGP
# segment-routing traffic-eng segment-list MR3_LU1_IGP index 10 mpls adjacency 10.88.38.41
# segment-routing traffic-eng segment-list MR3_LU2_IGP
# segment-routing traffic-eng segment-list MR3_LU2_IGP index 10 mpls adjacency 10.88.38.42
# segment-routing traffic-eng segment-list MR3_MG1_IGP
# segment-routing traffic-eng segment-list MR3_MG1_IGP index 10 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MR3_MG2_IGP
# segment-routing traffic-eng segment-list MR3_MG2_IGP index 10 mpls adjacency 10.88.38.20
# segment-routing traffic-eng segment-list MR3_MW1_IGP
# segment-routing traffic-eng segment-list MR3_MW1_IGP index 10 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_MW2_IGP
# segment-routing traffic-eng segment-list MR3_MW2_IGP index 10 mpls adjacency 10.88.38.14
#
# segment-routing traffic-eng segment-list MR3_AR1_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_AR1_SID1 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_AR1_SID1 index 30 mpls adjacency 10.88.38.11
# segment-routing traffic-eng segment-list MR3_AR1_SID2 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_AR1_SID2 index 20 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MR3_AR1_SID2 index 30 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MR3_AR1_SID2 index 40 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_AR1_SID2 index 50 mpls adjacency 10.88.38.11
# segment-routing traffic-eng segment-list MR3_AR2_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_AR2_SID1 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_AR2_SID1 index 30 mpls adjacency 10.88.38.7
# segment-routing traffic-eng segment-list MR3_AR2_SID1 index 40 mpls adjacency 10.88.38.12
# segment-routing traffic-eng segment-list MR3_AR2_SID2 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_AR2_SID2 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_AR2_SID2 index 30 mpls adjacency 10.88.38.20
# segment-routing traffic-eng segment-list MR3_AR2_SID2 index 40 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MR3_AR2_SID2 index 50 mpls adjacency 10.88.38.14
# segment-routing traffic-eng segment-list MR3_AR2_SID2 index 60 mpls adjacency 10.88.38.12
# segment-routing traffic-eng segment-list MR3_DO1_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_DO1_SID1 index 20 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MR3_DO1_SID1 index 30 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MR3_DO1_SID2 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_DO1_SID2 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_DO1_SID2 index 30 mpls adjacency 10.88.38.11
# segment-routing traffic-eng segment-list MR3_DO1_SID2 index 40 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_DO1_SID2 index 50 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MR3_DO2_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_DO2_SID1 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_DO2_SID1 index 30 mpls adjacency 10.88.38.20
# segment-routing traffic-eng segment-list MR3_DO2_SID1 index 40 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MR3_DO2_SID2 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_DO2_SID2 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_DO2_SID2 index 30 mpls adjacency 10.88.38.7
# segment-routing traffic-eng segment-list MR3_DO2_SID2 index 40 mpls adjacency 10.88.38.12
# segment-routing traffic-eng segment-list MR3_DO2_SID2 index 50 mpls adjacency 10.88.38.14
# segment-routing traffic-eng segment-list MR3_DO2_SID2 index 60 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MR3_KJ3_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_KJ3_SID1 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_KJ3_SID1 index 30 mpls adjacency 10.88.38.8
# segment-routing traffic-eng segment-list MR3_KJ3_SID2 index 10 mpls adjacency 10.88.38.4
# segment-routing traffic-eng segment-list MR3_KJ3_SID2 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_KJ3_SID2 index 30 mpls adjacency 10.88.38.7
# segment-routing traffic-eng segment-list MR3_KJ3_SID2 index 40 mpls adjacency 10.88.38.9
# segment-routing traffic-eng segment-list MR3_KJ3_SID2 index 50 mpls adjacency 10.88.38.8
# segment-routing traffic-eng segment-list MR3_KJ4_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_KJ4_SID1 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_KJ4_SID1 index 30 mpls adjacency 10.88.38.8
# segment-routing traffic-eng segment-list MR3_KJ4_SID1 index 40 mpls adjacency 10.88.38.9
# segment-routing traffic-eng segment-list MR3_KJ4_SID2 index 10 mpls adjacency 10.88.38.4
# segment-routing traffic-eng segment-list MR3_KJ4_SID2 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_KJ4_SID2 index 30 mpls adjacency 10.88.38.7
# segment-routing traffic-eng segment-list MR3_KJ4_SID2 index 40 mpls adjacency 10.88.38.9
# segment-routing traffic-eng segment-list MR3_LU1_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_LU1_SID1 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_LU1_SID1 index 30 mpls adjacency 10.88.38.8
# segment-routing traffic-eng segment-list MR3_LU1_SID1 index 40 mpls adjacency 10.88.38.41
# segment-routing traffic-eng segment-list MR3_LU1_SID2 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_LU1_SID2 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_LU1_SID2 index 30 mpls adjacency 10.88.38.11
# segment-routing traffic-eng segment-list MR3_LU1_SID2 index 40 mpls adjacency 10.88.38.42
# segment-routing traffic-eng segment-list MR3_LU1_SID2 index 50 mpls adjacency 10.88.38.41
# segment-routing traffic-eng segment-list MR3_LU2_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_LU2_SID1 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_LU2_SID1 index 30 mpls adjacency 10.88.38.41
# segment-routing traffic-eng segment-list MR3_LU2_SID1 index 40 mpls adjacency 10.88.38.42
# segment-routing traffic-eng segment-list MR3_LU2_SID2 index 10 mpls adjacency 10.88.38.9
# segment-routing traffic-eng segment-list MR3_LU2_SID2 index 20 mpls adjacency 10.88.38.7
# segment-routing traffic-eng segment-list MR3_LU2_SID2 index 30 mpls adjacency 10.88.38.12
# segment-routing traffic-eng segment-list MR3_LU2_SID2 index 40 mpls adjacency 10.88.38.11
# segment-routing traffic-eng segment-list MR3_LU2_SID2 index 50 mpls adjacency 10.88.38.42
# segment-routing traffic-eng segment-list MR3_MG1_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MG1_SID1 index 20 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MR3_MG1_SID2 index 10 mpls adjacency 10.88.38.4
# segment-routing traffic-eng segment-list MR3_MG1_SID2 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_MG1_SID2 index 30 mpls adjacency 10.88.38.20
# segment-routing traffic-eng segment-list MR3_MG1_SID2 index 40 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MR3_MG2_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MG2_SID1 index 20 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MR3_MG2_SID1 index 30 mpls adjacency 10.88.38.20
# segment-routing traffic-eng segment-list MR3_MG2_SID2 index 10 mpls adjacency 10.88.38.4
# segment-routing traffic-eng segment-list MR3_MG2_SID2 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_MG2_SID2 index 30 mpls adjacency 10.88.38.20
# segment-routing traffic-eng segment-list MR3_MW1_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MW1_SID1 index 20 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MR3_MW1_SID1 index 30 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MR3_MW1_SID1 index 40 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_MW1_SID2 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MW1_SID2 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_MW1_SID2 index 30 mpls adjacency 10.88.38.11
# segment-routing traffic-eng segment-list MR3_MW1_SID2 index 40 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_MW1_SID3 index 10 mpls adjacency 10.88.38.4
# segment-routing traffic-eng segment-list MR3_MW1_SID3 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_MW1_SID3 index 30 mpls adjacency 10.88.38.14
# segment-routing traffic-eng segment-list MR3_MW1_SID3 index 40 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_MW1_SID4 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MW1_SID4 index 20 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_MW2_SID1 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MW2_SID1 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_MW2_SID1 index 30 mpls adjacency 10.88.38.20
# segment-routing traffic-eng segment-list MR3_MW2_SID1 index 40 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MR3_MW2_SID1 index 50 mpls adjacency 10.88.38.14
# segment-routing traffic-eng segment-list MR3_MW2_SID2 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MW2_SID2 index 20 mpls adjacency 10.88.38.6
# segment-routing traffic-eng segment-list MR3_MW2_SID2 index 30 mpls adjacency 10.88.38.7
# segment-routing traffic-eng segment-list MR3_MW2_SID2 index 40 mpls adjacency 10.88.38.12
# segment-routing traffic-eng segment-list MR3_MW2_SID2 index 50 mpls adjacency 10.88.38.14
# segment-routing traffic-eng segment-list MR3_MW2_SID3 index 10 mpls adjacency 10.88.38.4
# segment-routing traffic-eng segment-list MR3_MW2_SID3 index 20 mpls adjacency 10.88.38.2
# segment-routing traffic-eng segment-list MR3_MW2_SID3 index 30 mpls adjacency 10.88.38.14
# segment-routing traffic-eng segment-list MR3_MW2_SID4 index 10 mpls adjacency 10.88.38.1
# segment-routing traffic-eng segment-list MR3_MW2_SID4 index 20 mpls adjacency 10.88.38.13
# segment-routing traffic-eng segment-list MR3_MW2_SID4 index 30 mpls adjacency 10.88.38.14
#
# segment-routing traffic-eng policy MR3_AR1
# segment-routing traffic-eng policy MR3_AR1 color 11 end-point ipv4 10.88.38.11
# segment-routing traffic-eng policy MR3_AR1 autoroute
# segment-routing traffic-eng policy MR3_AR1 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_AR1 autoroute include ipv4 10.88.38.11/32
# segment-routing traffic-eng policy MR3_AR1 candidate-paths
# segment-routing traffic-eng policy MR3_AR1 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_AR1 candidate-paths preference 1 explicit segment-list MR3_AR1_IGP
# segment-routing traffic-eng policy MR3_AR1 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_AR1 candidate-paths preference 200 explicit segment-list MR3_AR1_SID1
# segment-routing traffic-eng policy MR3_AR1 candidate-paths preference 200 explicit segment-list MR3_AR1_SID2
# segment-routing traffic-eng policy MR3_AR2
# segment-routing traffic-eng policy MR3_AR2 color 12 end-point ipv4 10.88.38.12
# segment-routing traffic-eng policy MR3_AR2 autoroute
# segment-routing traffic-eng policy MR3_AR2 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_AR2 autoroute include ipv4 10.88.38.12/32
# segment-routing traffic-eng policy MR3_AR2 candidate-paths
# segment-routing traffic-eng policy MR3_AR2 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_AR2 candidate-paths preference 1 explicit segment-list MR3_AR2_IGP
# segment-routing traffic-eng policy MR3_AR2 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_AR2 candidate-paths preference 200 explicit segment-list MR3_AR2_SID1
# segment-routing traffic-eng policy MR3_AR2 candidate-paths preference 200 explicit segment-list MR3_AR2_SID2
# segment-routing traffic-eng policy MR3_DO1
# segment-routing traffic-eng policy MR3_DO1 color 15 end-point ipv4 10.88.38.15
# segment-routing traffic-eng policy MR3_DO1 autoroute
# segment-routing traffic-eng policy MR3_DO1 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_DO1 autoroute include ipv4 10.88.38.15/32
# segment-routing traffic-eng policy MR3_DO1 candidate-paths
# segment-routing traffic-eng policy MR3_DO1 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_DO1 candidate-paths preference 1 explicit segment-list MR3_DO1_IGP
# segment-routing traffic-eng policy MR3_DO1 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_DO1 candidate-paths preference 200 explicit segment-list MR3_DO1_SID1
# segment-routing traffic-eng policy MR3_DO1 candidate-paths preference 200 explicit segment-list MR3_DO1_SID2
# segment-routing traffic-eng policy MR3_DO2
# segment-routing traffic-eng policy MR3_DO2 color 16 end-point ipv4 10.88.38.16
# segment-routing traffic-eng policy MR3_DO2 autoroute
# segment-routing traffic-eng policy MR3_DO2 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_DO2 autoroute include ipv4 10.88.38.16/32
# segment-routing traffic-eng policy MR3_DO2 candidate-paths
# segment-routing traffic-eng policy MR3_DO2 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_DO2 candidate-paths preference 1 explicit segment-list MR3_DO2_IGP
# segment-routing traffic-eng policy MR3_DO2 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_DO2 candidate-paths preference 200 explicit segment-list MR3_DO2_SID1
# segment-routing traffic-eng policy MR3_DO2 candidate-paths preference 200 explicit segment-list MR3_DO2_SID2
# segment-routing traffic-eng policy MR3_KJ3
# segment-routing traffic-eng policy MR3_KJ3 color 8 end-point ipv4 10.88.38.8
# segment-routing traffic-eng policy MR3_KJ3 autoroute
# segment-routing traffic-eng policy MR3_KJ3 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_KJ3 autoroute include ipv4 10.88.38.8/32
# segment-routing traffic-eng policy MR3_KJ3 candidate-paths
# segment-routing traffic-eng policy MR3_KJ3 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_KJ3 candidate-paths preference 1 explicit segment-list MR3_KJ3_IGP
# segment-routing traffic-eng policy MR3_KJ3 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_KJ3 candidate-paths preference 200 explicit segment-list MR3_KJ3_SID1
# segment-routing traffic-eng policy MR3_KJ3 candidate-paths preference 200 explicit segment-list MR3_KJ3_SID2
# segment-routing traffic-eng policy MR3_KJ4
# segment-routing traffic-eng policy MR3_KJ4 color 9 end-point ipv4 10.88.38.9
# segment-routing traffic-eng policy MR3_KJ4 autoroute
# segment-routing traffic-eng policy MR3_KJ4 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_KJ4 autoroute include ipv4 10.88.38.9/32
# segment-routing traffic-eng policy MR3_KJ4 candidate-paths
# segment-routing traffic-eng policy MR3_KJ4 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_KJ4 candidate-paths preference 1 explicit segment-list MR3_KJ4_IGP
# segment-routing traffic-eng policy MR3_KJ4 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_KJ4 candidate-paths preference 200 explicit segment-list MR3_KJ4_SID1
# segment-routing traffic-eng policy MR3_KJ4 candidate-paths preference 200 explicit segment-list MR3_KJ4_SID2
# segment-routing traffic-eng policy MR3_LU1
# segment-routing traffic-eng policy MR3_LU1 color 41 end-point ipv4 10.88.38.41
# segment-routing traffic-eng policy MR3_LU1 autoroute
# segment-routing traffic-eng policy MR3_LU1 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_LU1 autoroute include ipv4 10.88.38.41/32
# segment-routing traffic-eng policy MR3_LU1 candidate-paths
# segment-routing traffic-eng policy MR3_LU1 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_LU1 candidate-paths preference 1 explicit segment-list MR3_LU1_IGP
# segment-routing traffic-eng policy MR3_LU1 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_LU1 candidate-paths preference 200 explicit segment-list MR3_LU1_SID1
# segment-routing traffic-eng policy MR3_LU1 candidate-paths preference 200 explicit segment-list MR3_LU1_SID2
# segment-routing traffic-eng policy MR3_LU2
# segment-routing traffic-eng policy MR3_LU2 color 42 end-point ipv4 10.88.38.42
# segment-routing traffic-eng policy MR3_LU2 autoroute
# segment-routing traffic-eng policy MR3_LU2 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_LU2 autoroute include ipv4 10.88.38.42/32
# segment-routing traffic-eng policy MR3_LU2 candidate-paths
# segment-routing traffic-eng policy MR3_LU2 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_LU2 candidate-paths preference 1 explicit segment-list MR3_LU2_IGP
# segment-routing traffic-eng policy MR3_LU2 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_LU2 candidate-paths preference 200 explicit segment-list MR3_LU2_SID1
# segment-routing traffic-eng policy MR3_LU2 candidate-paths preference 200 explicit segment-list MR3_LU2_SID2
# segment-routing traffic-eng policy MR3_MG1
# segment-routing traffic-eng policy MR3_MG1 color 19 end-point ipv4 10.88.38.19
# segment-routing traffic-eng policy MR3_MG1 autoroute
# segment-routing traffic-eng policy MR3_MG1 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_MG1 autoroute include ipv4 10.88.38.19/32
# segment-routing traffic-eng policy MR3_MG1 candidate-paths
# segment-routing traffic-eng policy MR3_MG1 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_MG1 candidate-paths preference 1 explicit segment-list MR3_MG1_IGP
# segment-routing traffic-eng policy MR3_MG1 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_MG1 candidate-paths preference 200 explicit segment-list MR3_MG1_SID1
# segment-routing traffic-eng policy MR3_MG1 candidate-paths preference 200 explicit segment-list MR3_MG1_SID2
# segment-routing traffic-eng policy MR3_MG2
# segment-routing traffic-eng policy MR3_MG2 color 20 end-point ipv4 10.88.38.20
# segment-routing traffic-eng policy MR3_MG2 autoroute
# segment-routing traffic-eng policy MR3_MG2 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_MG2 autoroute include ipv4 10.88.38.20/32
# segment-routing traffic-eng policy MR3_MG2 candidate-paths
# segment-routing traffic-eng policy MR3_MG2 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_MG2 candidate-paths preference 1 explicit segment-list MR3_MG2_IGP
# segment-routing traffic-eng policy MR3_MG2 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_MG2 candidate-paths preference 200 explicit segment-list MR3_MG2_SID1
# segment-routing traffic-eng policy MR3_MG2 candidate-paths preference 200 explicit segment-list MR3_MG2_SID2
# segment-routing traffic-eng policy MR3_MW1
# segment-routing traffic-eng policy MR3_MW1 color 13 end-point ipv4 10.88.38.13
# segment-routing traffic-eng policy MR3_MW1 autoroute
# segment-routing traffic-eng policy MR3_MW1 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_MW1 autoroute include ipv4 10.88.38.13/32
# segment-routing traffic-eng policy MR3_MW1 candidate-paths
# segment-routing traffic-eng policy MR3_MW1 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_MW1 candidate-paths preference 1 explicit segment-list MR3_MW1_IGP
# segment-routing traffic-eng policy MR3_MW1 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_MW1 candidate-paths preference 200 explicit segment-list MR3_MW1_SID1
# segment-routing traffic-eng policy MR3_MW1 candidate-paths preference 200 explicit segment-list MR3_MW1_SID2
# segment-routing traffic-eng policy MR3_MW1 candidate-paths preference 200 explicit segment-list MR3_MW1_SID3
# segment-routing traffic-eng policy MR3_MW1 candidate-paths preference 200 explicit segment-list MR3_MW1_SID4
# segment-routing traffic-eng policy MR3_MW2
# segment-routing traffic-eng policy MR3_MW2 color 14 end-point ipv4 10.88.38.14
# segment-routing traffic-eng policy MR3_MW2 autoroute
# segment-routing traffic-eng policy MR3_MW2 autoroute force-sr-include
# segment-routing traffic-eng policy MR3_MW2 autoroute include ipv4 10.88.38.14/32
# segment-routing traffic-eng policy MR3_MW2 candidate-paths
# segment-routing traffic-eng policy MR3_MW2 candidate-paths preference 1
# segment-routing traffic-eng policy MR3_MW2 candidate-paths preference 1 explicit segment-list MR3_MW2_IGP
# segment-routing traffic-eng policy MR3_MW2 candidate-paths preference 200
# segment-routing traffic-eng policy MR3_MW2 candidate-paths preference 200 explicit segment-list MR3_MW2_SID1
# segment-routing traffic-eng policy MR3_MW2 candidate-paths preference 200 explicit segment-list MR3_MW2_SID2
# segment-routing traffic-eng policy MR3_MW2 candidate-paths preference 200 explicit segment-list MR3_MW2_SID3
# segment-routing traffic-eng policy MR3_MW2 candidate-paths preference 200 explicit segment-list MR3_MW2_SID4

# %%
mm=open('myfiles/srte2.txt').readlines()
for a in mm:
    if 'DO' in a or 'conf'.upper() in a.upper() or 'commit' in a or 'TZ' in a :
        print(a,end='')
# Out:
# TZ-MG-NCS-560-7-SR02
# Config MOP
# conf t
# no segment-routing traffic-eng segment-list MG2_DO1_SID1
# no segment-routing traffic-eng segment-list MG2_DO1_SID2
# no segment-routing traffic-eng segment-list MG2_DO2_SID1
# no segment-routing traffic-eng segment-list MG2_DO2_SID2
# commit
# segment-routing traffic-eng segment-list MG2_DO1_IGP
# segment-routing traffic-eng segment-list MG2_DO1_IGP index 10 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MG2_DO2_IGP
# segment-routing traffic-eng segment-list MG2_DO2_IGP index 10 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MG2_DO1_SID1 index 10 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MG2_DO1_SID1 index 20 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MG2_DO1_SID2 index 10 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MG2_DO1_SID2 index 20 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MG2_DO2_SID1 index 10 mpls adjacency 10.88.38.19
# segment-routing traffic-eng segment-list MG2_DO2_SID1 index 20 mpls adjacency 10.88.38.15
# segment-routing traffic-eng segment-list MG2_DO2_SID1 index 30 mpls adjacency 10.88.38.16
# segment-routing traffic-eng segment-list MG2_DO2_SID2 index 10 mpls adjacency 10.88.38.16
# segment-routing traffic-eng policy MG2_DO1
# segment-routing traffic-eng policy MG2_DO1 color 15 end-point ipv4 10.88.38.15
# segment-routing traffic-eng policy MG2_DO1 autoroute
# segment-routing traffic-eng policy MG2_DO1 autoroute force-sr-include
# segment-routing traffic-eng policy MG2_DO1 autoroute include ipv4 10.88.38.15/32
# segment-routing traffic-eng policy MG2_DO1 candidate-paths
# segment-routing traffic-eng policy MG2_DO1 candidate-paths preference 1
# segment-routing traffic-eng policy MG2_DO1 candidate-paths preference 1 explicit segment-list MG2_DO1_IGP
# segment-routing traffic-eng policy MG2_DO1 candidate-paths preference 200
# segment-routing traffic-eng policy MG2_DO1 candidate-paths preference 200 explicit segment-list MG2_DO1_SID1
# segment-routing traffic-eng policy MG2_DO1 candidate-paths preference 200 explicit segment-list MG2_DO1_SID2
# segment-routing traffic-eng policy MG2_DO2
# segment-routing traffic-eng policy MG2_DO2 color 16 end-point ipv4 10.88.38.16
# segment-routing traffic-eng policy MG2_DO2 autoroute
# segment-routing traffic-eng policy MG2_DO2 autoroute force-sr-include
# segment-routing traffic-eng policy MG2_DO2 autoroute include ipv4 10.88.38.16/32
# segment-routing traffic-eng policy MG2_DO2 candidate-paths
# segment-routing traffic-eng policy MG2_DO2 candidate-paths preference 1
# segment-routing traffic-eng policy MG2_DO2 candidate-paths preference 1 explicit segment-list MG2_DO2_IGP
# segment-routing traffic-eng policy MG2_DO2 candidate-paths preference 200
# segment-routing traffic-eng policy MG2_DO2 candidate-paths preference 200 explicit segment-list MG2_DO2_SID1
# segment-routing traffic-eng policy MG2_DO2 candidate-paths preference 200 explicit segment-list MG2_DO2_SID2

# %%
ww = """
Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.7.11     1   FULL/--      00:00:32  10.150.18.161   vlan132
10.150.7.34     1   FULL/--      00:00:38  10.150.18.226   vlan136

            OSPF Router with ID (10.150.17.3) (Process ID 3)

Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.7.8      1   FULL/--      00:00:39  10.150.18.165   vlan152
10.150.7.35     1   FULL/--      00:00:39  10.150.18.218   vlan16
172.30.78.13    1   FULL/--      00:00:39  172.30.78.134   vlan78
172.30.80.13    1   FULL/--      00:00:39  172.30.80.134   vlan1013
172.30.81.13    1   FULL/--      00:00:39  172.30.81.134   vlan608
172.30.191.98   1   FULL/--      00:00:39  172.30.191.149  vlan575

            OSPF Router with ID (10.150.7.23) (Process ID 13)

Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.7.48     1   FULL/--      00:00:39  10.150.17.70    vlan18
10.150.7.9      1   FULL/--      00:00:39  10.150.18.69    vlan627
10.150.7.36     1   FULL/--      00:00:39  10.150.18.230   vlan156
172.30.80.15    1   FULL/--      00:00:39  172.30.80.142   vlan1015
172.30.81.15    1   FULL/--      00:00:39  172.30.81.142   vlan609
172.30.191.104  1   FULL/--      00:00:39  172.30.191.153  vlan576
172.30.72.9     1   FULL/--      00:00:39  172.30.72.118   vlan516
172.30.73.9     1   FULL/--      00:00:38  172.30.73.118   vlan536
172.30.76.10    1   FULL/--      00:00:39  172.30.76.122   vlan519
172.30.78.9     1   FULL/DR      00:00:39  172.30.78.118   vlan504
172.30.82.9     1   FULL/--      00:00:39  172.30.82.118   vlan555
172.30.78.15    1   FULL/--      00:00:40  172.30.78.142   vlan77

            OSPF Router with ID (10.150.7.26) (Process ID 23)

Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.7


Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.7.29     1   FULL/--      00:00:34  10.150.18.241   vlan216
10.150.7.15     1   FULL/--      00:00:37  10.159.1.46     vlan34

            OSPF Router with ID (10.150.7.43) (Process ID 10)

Neighbor ID     Pri State        DeadTime  Address         Interface
10.159.1.18     1   FULL/DR      00:00:37  10.159.1.22     vlan472
10.150.7.30     1   FULL/--      00:00:38  10.159.1.25     vlan473
10.150.7.12     1   FULL/--      00:00:34  10.159.1.38     vlan202

            OSPF Router with ID (10.150.7.44) (Process ID 15)

Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.2.161    1   FULL/BDR     00:00:30  10.150.2.165    vlan424

            OSPF Router with ID (10.150.2.149) (Process ID 20)

Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.7.17     1   FULL/--      00:00:39  10.150.2.150    vlan426

            OSPF Router with ID (10.150.7.45) (Process ID 11)

Neighbor ID     Pri State        DeadTime  Address         Interface
10.150.1.210    1   FULL/--      00:00:40  10.150.1.214    vlan703


"""
pp = """611
906
907
705
431
612
909
706
910
"""
pp2 = """
655
314
656
315
"""

ff = open(r"C:\Users\chugorji\OneDrive - Cisco\Documents\NTC & WTC nodes dump\NTC_8905E_PS02.log").read()
tt=[]
ip=''; vl=''; mm=''; t=20
vrf=set()
for a in ff.split('$\n'):
    a=a.lower()    
    if 'ip vrf forwarding' in a and 'vlan' in a:
        [print(a.replace('vlan','Be20.').replace('ip vrf forwarding vrf_ent', 'vrf ent').replace('ip vrf forwarding vrf_signal', 'vrf sig_cn').replace('ip vrf forwarding vrf_omm','vrf om_cn').replace('ip vrf forwarding vrf_gi','vrf Gi').replace('ip vrf forwarding vrf_gn', 'vrf media_cn').replace('ip vrf forwarding vrf_media','vrf media_cn').replace('ip address','ipv4 address')+'  encapsulation dot1q '+r+'\n') for r in pp.split('\n') if r==a.split('\n')[0].replace('interface vlan','')]
        [vrf.add(a.split('\n')[2].split(' ')[-1]) for r in pp.split('\n') if r==a.split('\n')[0].replace('interface vlan','')]
    
    if 'interface vlan' in a and 'vrrp' in a:
        for r in pp.split('\n'):
            for e in a.split('\n') :
                if 'vlan' in e :
                    vl=e.replace('interface vlan','').strip()
                    
                if 'ipv4' in e:
                    ip=e.split()[-1]    
            
            if vl == r:
                t+=1
                mm=  f""" interface Be20.{r}
  address-family ipv4
   vrrp {t}
    priority 120
    preempt delay 30
    address {ip}
   !
  !
 !"""       
                #print(mm)  
                tt.append(mm)
print('\n'.join(tt) )  

rr=''; vv=''; p2p=''
for a in ff.split('ospfv2>')[1].split('\n')    :

    if 'interface' in a or 'vrf' in  a  or 'router-id' in a or 'point-to' in a: 
        #print(a)
        if 'vrf ' in a : vv=a
        if 'router-id' in a: rr=a
        if 'point-to' in a : p2p=a
        if 'interface' in a: 
            c=a.split('vlan')[-1] 
            #print(c)
            for ss in pp.split('\n') :
                if ss == c:
                    print(f"""
{vv}
{rr}
  area 0.0.0.0
  interface Be20:{c}
    {p2p}
""")

# for a in ww.split('\n'):
#     if 'vlan' in a:
#         for ss in pp.split('\n') :
#            if ss == a.split('vlan')[-1]:
#                 print(a)


# for a in ff.split('static>')[1].split('\n'):
#     if 'ip route' in a : print(a.split(' ')[6])
# print(len(ff.split('static>')[1].split('\n')))    
print(vrf)     
import re
#FOR STATIC ROUTES
rr = open(r"C:\Users\chugorji\OneDrive - Cisco\Documents\NTC_8905E_PS02 ROUTES.txt").read()

for a in rr.split('\n'):
    a=a.lower() 
    #if 'forwarding route' in a : print(a)
    if 'vlan' in a and 'static' in a:
        for r in pp.split('\n'):
            if re.split(r'\s+', a)[3].split('n')[1] == r:
                #print(a)
                [print(re.split(r'\s+', a)[3],sts.replace('bfd enable name', 'bfd fast-detect minimum-interval 300 multiplier 3 description').replace('ip route', 'router static').replace('VRF_Ent', 'ent address-family ipv4 unicast ').replace('VRF_Signal', 'sig_cn address-family ipv4 unicast ').replace('VRF_OMM','om_cn address-family ipv4 unicast ').replace('VRF_Gi','Gi address-family ipv4 unicast ').replace('VRF_Gn', 'media_cn address-family ipv4 unicast ').replace('VRF_Media','media_cn address-family ipv4 unicast ').replace('NAS', 'NAS address-family ipv4 unicast ')) for sts in ff.split('static>')[1].split('\n') if 'ip route' in sts and re.split(r'\s+', a)[1].split('/')[0] == sts.split(' ')[4] and  re.split(r'\s+', a)[2] == sts.split(' ')[6] ]
                #[print(sts, '\n', a) for sts in ff.split('static>')[1].split('\n') if 'ip route' in sts and re.split(r'\s+', a)[1].split('/')[0] == sts.split(' ')[4] and  re.split(r'\s+', a)[2] == sts.split(' ')[6] ]
                #ip route vrf sig_cn 10.150.12.6 255.255.255.255 10.150.12.85 bfd enable name uMAC_GrGaLIG
                #router static vrf media_cn address-family ipv4 unicast  41.77.0.129 255.255.255.255 10.150.12.73 bfd enable name MME_Roaming

# FOR BFD

for a in ff.split('bfd>')[1].split('$\n'):
    [print (a) for p in pp.split('\n') for aa in a.split('\n') if 'multiplier' in a and 'interfa' in aa and aa.split('vlan')[-1]==p]           

ip=80; a= 3291
for b in vrf:
    interface= f"""interface Bundle-Ether20.{a}
description <<< L3_INTERCONNECTION_4_{b.upper()} >>>
vrf {b.replace('vrf_ent', 'ent').replace('vrf_signal', 'sig_cn').replace('vrf_omm','om_cn').replace('vrf_gi','Gi').replace('vrf_gn', 'media_cn').replace('vrf_media','media_cn')}
ipv4 address 10.29.7.{ip} 255.255.255.254
encapsulation dot1q {a}
!
router bgp 64700
 vrf {b.replace('vrf_ent', 'ent').replace('vrf_signal', 'sig_cn').replace('vrf_omm','om_cn').replace('vrf_gi','Gi').replace('vrf_gn', 'media_cn').replace('vrf_media','media_cn')}
  neighbor 10.29.7.{ip+1}
  remote-as 37288
  description <<< L3_INTERCONNECTION_4_{b.upper()} >>>
  address-family ipv4 unicast
   route-policy PASS_ALL in
   route-policy PASS_ALL out
  !
 !
"""
    print(interface)
    ip+=4
    a+=2
# Out:
# interface Be20.431
#   description [gn][to][dns]
#   vrf media_cn
#   ipv4 address 41.77.0.25 255.255.255.240
#   encapsulation dot1q 431
#
# interface Be20.611
#   description [to_ntc_ericsson_zmpdns1&2_oam]
#   vrf om_cn
#   ipv4 address 10.150.1.3 255.255.255.224
#   encapsulation dot1q 611
#
# interface Be20.612
#   description [to_ntc_ericsson_zmpdns1&2_traffic]
#   vrf Gi
#   ipv4 address 10.150.2.78 255.255.255.240
#   encapsulation dot1q 612
#
# interface Be20.906
#   description [luspdns01_pdns_host_om]
#   vrf om_cn
#   ipv4 address 10.150.1.131 255.255.255.248
#   encapsulation dot1q 906
#
# interface Be20.907
#   description [luspdns01_pdns_om_sp1]
#   vrf om_cn
#   ipv4 address 10.150.1.139 255.255.255.248
#   encapsulation dot1q 907
#
# interface Be20.909
#   description [luspdns01_pdns_sig_sp1]
#   vrf Gi
#   ipv4 address 10.150.1.147 255.255.255.240
#   encapsulation dot1q 909
#
#  interface Be20.431
#   address-family ipv4
#    vrrp 21
#     priority 120
#     preempt delay 30
#     address 41.77.0.26
#    !
#   !
#  !
#  interface Be20.611
#   address-family ipv4
#    vrrp 22
#     priority 120
#     preempt delay 30
#     address 10.150.1.1
#    !
#   !
#  !
#  interface Be20.612
#   address-family ipv4
#    vrrp 23
#     priority 120
#     preempt delay 30
#     address 10.150.2.65
#    !
#   !
#  !
#  interface Be20.906
#   address-family ipv4
#    vrrp 24
#     priority 120
#     preempt delay 30
#     address 10.150.1.129
#    !
#   !
#  !
#  interface Be20.907
#   address-family ipv4
#    vrrp 25
#     priority 120
#     preempt delay 30
#     address 10.150.1.137
#    !
#   !
#  !
#  interface Be20.909
#   address-family ipv4
#    vrrp 26
#     priority 120
#     preempt delay 30
#     address 10.150.1.145
#    !
#   !
#  !
# {'vrf_gi', 'vrf_omm', 'vrf_gn'}
# vlan909 router static vrf Gi address-family ipv4 unicast  10.150.1.193 255.255.255.255 10.150.1.148 metric 100 name LUSPNS01[pDNS_SIG_SP1_FEE1]
# vlan909 router static vrf Gi address-family ipv4 unicast  10.150.1.193 255.255.255.255 10.150.1.149 metric 100 name LUSPNS01[pDNS_SIG_SP1_FEE2]
# vlan909 router static vrf Gi address-family ipv4 unicast  10.150.1.193 255.255.255.255 10.150.1.150 metric 100 name LUSPNS01[pDNS_SIG_SP1_FEE3]
# vlan909 router static vrf Gi address-family ipv4 unicast  10.150.1.193 255.255.255.255 10.150.1.151 metric 100 name LUSPNS01[pDNS_SIG_SP1_FEE4]
# interface Bundle-Ether20.3291
# description <<< L3_INTERCONNECTION_4_VRF_GI >>>
# vrf Gi
# ipv4 address 10.29.7.80 255.255.255.254
# encapsulation dot1q 3291
# !
# router bgp 64700
#  vrf Gi
#   neighbor 10.29.7.81
#   remote-as 37288
#   description <<< L3_INTERCONNECTION_4_VRF_GI >>>
#   address-family ipv4 unicast
#    route-policy PASS_ALL in
#    route-policy PASS_ALL out
#   !
#  !
#
# interface Bundle-Ether20.3293
# description <<< L3_INTERCONNECTION_4_VRF_OMM >>>
# vrf om_cn
# ipv4 address 10.29.7.84 255.255.255.254
# encapsulation dot1q 3293
# !
# router bgp 64700
#  vrf om_cn
#   neighbor 10.29.7.85
#   remote-as 37288
#   description <<< L3_INTERCONNECTION_4_VRF_OMM >>>
#   address-family ipv4 unicast
#    route-policy PASS_ALL in
#    route-policy PASS_ALL out
#   !
#  !
#
# interface Bundle-Ether20.3295
# description <<< L3_INTERCONNECTION_4_VRF_GN >>>
# vrf media_cn
# ipv4 address 10.29.7.88 255.255.255.254
# encapsulation dot1q 3295
# !
# router bgp 64700
#  vrf media_cn
#   neighbor 10.29.7.89
#   remote-as 37288
#   description <<< L3_INTERCONNECTION_4_VRF_GN >>>
#   address-family ipv4 unicast
#    route-policy PASS_ALL in
#    route-policy PASS_ALL out
#   !
#  !

# %%
ff = open(r"C:\Users\chugorji\OneDrive - Cisco\Documents\NTC & WTC nodes dump\NTC_8905E_PS01.log").read()
c=''
sgint=[]
swint=[]
mm=''
dd = {}
for a in ff.split('$\n'):
    a=a.lower()  
    if f'smartgroup {c}' in a and 'mode ' in a:
        sgt=a.split('\n')[0].split(' ')[-1]
        #print(sgt)
        sgint.append(sgt)

    # if f'interface smartgroup{c}' in a and ('vlan' in a or 'descrip' in a):
    #     [print(aa) for aa in a.split('\n') if 'vlan' in aa or 'descrip' in aa]

    if 'descrip' in a and 'vlan' not in a and 'no shutdown' in a:
        
        for h in a.split('\n'):
            if 'interface' in h: 
                mm=h.split(' ')[-1]
                dd.update({mm:''})
            if 'descrip' in h:
                cc=h.split('ion ')[-1]
                dd[mm]=cc

    if 'switchport' in a and 'smartgroup' not in a:
        for aa in a.split('\n'): 
            if 'interface' in aa:
                swp = aa.split(' ')[-1]
                #print(swp)
                swint.append(swp)

rr=set(swint) - set(sgint)
# print(len(rr),sorted(rr))
# print(len(swint), sorted(swint))  
# print(len(sgint),sorted(sgint)) 

for a in ff.split('$\n'):
    a=a.lower() 
    if 'switchport' in a and 'smartgroup' not in a:
        for aa in a.split('\n'): 
            if 'interface' in aa:
                swp = aa.split(' ')[-1]
                for oo in rr:
                    if swp == oo and dd.get(oo) is not None and 'dna' in dd.get(oo):
                        print(dd.get(oo))
                        print(a)
# Out:
# [connectivity_towrads_cisco_dna_prim]
#   interface gei-0/3/0/48
#     switchport mode trunk
#     switchport trunk vlan 920-921
#
# [connectivity_towrads_ip_dna_prim]
#   interface xgei-0/4/0/30
#     switchport mode trunk
#     switchport trunk vlan 920-921,929

# %%
vrf="""interface smartgroup4.35
  ip vrf forwarding VRF_Gn
  ip address 10.159.1.42 255.255.255.252
$
interface smartgroup4.112
  description [cgei-0/3/1/2][to][8905E_PS01][]
  ip vrf forwarding VRF_OMM
  ip address 10.150.18.157 255.255.255.252
$
interface smartgroup4.132
  description [cgei-0/3/1/2][to][8905E_PS01][]
  ip vrf forwarding VRF_Signal
  ip address 10.150.18.161 255.255.255.252
$
interface smartgroup4.142
  description [cgei-0/3/1/2][to][8905E_PS01][]
  ip vrf forwarding VRF_Signal
  ip address 10.150.18.218 255.255.255.252
$
interface smartgroup4.152
  description [cgei-0/3/1/2][to][8905E_PS01][]
  ip vrf forwarding VRF_Media
  ip address 10.150.18.165 255.255.255.252
$
interface smartgroup4.194
  ip vrf forwarding VRF_Gi
  ip address 10.150.15.82 255.255.255.252
$
interface smartgroup4.201
  ip vrf forwarding VRF_Ent
  ip address 10.159.1.34 255.255.255.252
$
interface smartgroup4.302
  ip vrf forwarding VRF_Gi_out
  ip address 10.157.7.10 255.255.255.252
$
interface smartgroup4.308
  ip vrf forwarding VRF_Gi_out
  ip address 10.157.107.18 255.255.255.252
$
interface smartgroup4.425
  description [cgei-0/3/1/2][to][8905E_PS01][]
  ip vrf forwarding VRF_IMS
  ip address 10.150.2.146 255.255.255.252
$
interface smartgroup4.627
  description [cgei-0/3/1/2][to][8905E_PS01][]
  ip vrf forwarding VRF_Media
  ip address 10.150.18.69 255.255.255.252
$
interface smartgroup4.829
  description [cgei-0/3/1/2][to][8905E_PS01][Media]
  ip vrf forwarding VRF_Media
  ip address 10.150.7.225 255.255.255.252
$
interface smartgroup4.831
  description [cgei-0/3/1/2][to][8905E_PS01][Media]
  ip vrf forwarding VRF_Media
  ip address 10.150.7.229 255.255.255.252
$
interface smartgroup4.833
  description [cgei-0/3/1/2][to][8905E_PS01][Media]
  ip vrf forwarding VRF_Media
  ip address 10.150.7.233 255.255.255.252
$
interface smartgroup4.1084
  description [IMS_OMM]
  ip vrf forwarding VRF_OMM
$
interface smartgroup4.2002
  ip vrf forwarding VRF_OMM
  ip address 192.168.56.1 255.255.255.252
$
"""
m=set()
for a in vrf.split('\n'):
    if 'vrf' in a: m.add(a.split(' ')[-1])

print(m)    
a=10
for s, a in enumerate(m, start=3001) :
    interface= f"""
interface Bundle-Ether1000.{s}
description <<< L3_INTERCONNECTION_4_{a} >>>
vrf {a}
ipv4 address x.x.x.x 255.255.255.252
encapsulation dot1q {s}
!
"""
    print(interface)
# Out:
# {'VRF_OMM', 'VRF_Signal', 'VRF_Ent', 'VRF_Media', 'VRF_IMS', 'VRF_Gi', 'VRF_Gi_out', 'VRF_Gn'}
#
# interface Bundle-Ether1000.3001
# description <<< L3_INTERCONNECTION_4_VRF_OMM >>>
# vrf VRF_OMM
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3001
# !
#
#
# interface Bundle-Ether1000.3002
# description <<< L3_INTERCONNECTION_4_VRF_Signal >>>
# vrf VRF_Signal
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3002
# !
#
#
# interface Bundle-Ether1000.3003
# description <<< L3_INTERCONNECTION_4_VRF_Ent >>>
# vrf VRF_Ent
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3003
# !
#
#
# interface Bundle-Ether1000.3004
# description <<< L3_INTERCONNECTION_4_VRF_Media >>>
# vrf VRF_Media
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3004
# !
#
#
# interface Bundle-Ether1000.3005
# description <<< L3_INTERCONNECTION_4_VRF_IMS >>>
# vrf VRF_IMS
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3005
# !
#
#
# interface Bundle-Ether1000.3006
# description <<< L3_INTERCONNECTION_4_VRF_Gi >>>
# vrf VRF_Gi
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3006
# !
#
#
# interface Bundle-Ether1000.3007
# description <<< L3_INTERCONNECTION_4_VRF_Gi_out >>>
# vrf VRF_Gi_out
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3007
# !
#
#
# interface Bundle-Ether1000.3008
# description <<< L3_INTERCONNECTION_4_VRF_Gn >>>
# vrf VRF_Gn
# ipv4 address x.x.x.x 255.255.255.252
# encapsulation dot1q 3008
# !

# %%
import json
import pandas as df
data = json.load(open(r'C:\Users\chugorji\Downloads\Audit Log-Table-root.json'))
#print(json.dumps(data, indent=4))
df = df.DataFrame(data)
# df =  df.DataFrame.from_dict(data)
10.157.4.208
10.182.20.200
10.26.208.216
10.26.216.128
10.26.216.216
10.182.15.0
10.182.19.0
10.182.15.144
10.26.208.128
10.182.19.144
10.150.14.161
10.150.14.162
10.150.14.163
10.150.14.164
10.150.14.165
10.150.14.166
10.150.14.167
10.150.14.168
10.150.14.169
10.150.14.170
10.150.14.172
10.150.14.208
10.182.20.64
10.182.20.128
10.182.20.192
100.200.254.0"""
for a in c.split('\n'):
    print(a.strip(),'/32')
# Out:
# 10.151.2.25 /32
# 10.151.2.26 /32
# 10.151.2.27 /32
# 10.151.2.28 /32
# 10.151.2.29 /32
# 10.151.2.30 /32
# 41.77.0.10 /32
# 41.77.0.15 /32
# 41.77.0.17 /32
# 41.77.0.18 /32
# 41.77.0.48 /32
# 41.77.0.49 /32
# 41.77.0.50 /32
# 41.77.0.51 /32
# 41.77.0.52 /32
# 41.77.0.53 /32
# 41.77.0.54 /32
# 41.77.0.55 /32
# 41.77.2.97 /32
# 41.77.2.98 /32
# 41.77.2.99 /32
# 41.77.2.100 /32
# 41.77.2.101 /32
# 41.77.2.102 /32
# 41.77.2.103 /32
# 41.77.2.104 /32
# 41.77.5.227 /32
# 41.77.5.228 /32
# 41.77.5.229 /32
# 41.77.5.230 /32
# 41.77.5.231 /32
# 41.77.5.232 /32
# 41.77.5.195 /32
# 41.77.5.196 /32
# 41.77.5.197 /32
# 41.77.5.198 /32
# 41.77.5.199 /32
# 41.77.5.200 /32
# 41.77.0.186 /32
# 41.77.0.187 /32
# 41.77.0.188 /32
# 41.77.0.189 /32
# 41.77.0.190 /32
# 41.77.0.191 /32
# 41.77.0.70 /32
# 41.77.0.71 /32
# 41.77.0.47 /32
# 10.151.2.17 /32
# 10.151.2.18 /32
# 10.151.2.19 /32
# 10.151.2.20 /32
# 10.151.2.21 /32
# 10.151.2.22 /32
# 10.151.2.23 /32
# 10.151.2.24 /32
# 10.151.2.31 /32
# 10.151.2.32 /32
# 10.151.2.33 /32
# 10.151.2.34 /32
# 10.151.2.35 /32
# 10.151.2.36 /32
# 10.157.114.203 /32
# 10.157.114.204 /32
# 10.157.114.205 /32
# 10.157.114.206 /32
# 10.157.114.207 /32
# 10.157.114.208 /32
# 10.157.4.203 /32
# 10.157.4.204 /32
# 10.157.4.205 /32
# 10.157.4.206 /32
# 10.157.4.207 /32
# 10.157.4.208 /32
# 10.182.20.200 /32
# 10.26.208.216 /32
# 10.26.216.128 /32
# 10.26.216.216 /32
# 10.182.15.0 /32
# 10.182.19.0 /32
# 10.182.15.144 /32
# 10.26.208.128 /32
# 10.182.19.144 /32
# 10.150.14.161 /32
# 10.150.14.162 /32
# 10.150.14.163 /32
# 10.150.14.164 /32
# 10.150.14.165 /32
# 10.150.14.166 /32
# 10.150.14.167 /32
# 10.150.14.168 /32
# 10.150.14.169 /32
# 10.150.14.170 /32
# 10.150.14.172 /32
# 10.150.14.208 /32
# 10.182.20.64 /32
# 10.182.20.128 /32
# 10.182.20.192 /32
# 100.200.254.0 /32
